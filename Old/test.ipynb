# %%
import matplotlib.pyplot as plt 
import cv2

# %%
img = plt.imread('Datasets/craters/test/images/015_png.rf.7d5b2091b6339c9480a171a59c52c3b9.jpg')

# %%
img =  cv2.resize(img,(128,128))

# %%
plt.imshow(img)
